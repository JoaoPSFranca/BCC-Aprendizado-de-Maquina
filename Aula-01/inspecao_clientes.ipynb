# %%
# Importe a biblioteca pandas.
import pandas as pd

# %%
# Carregue o arquivo clientes_knn.csv em um DataFrame.
df = pd.read_csv('../Treinamento KNN/clientes_knn.csv')

# %%
# Exiba as primeiras e as últimas linhas da base de clientes.
df.head()
df.tail()
dados = df

# %%
# Descubra a quantidade de linhas e colunas da base.
df.shape

# %%
# Consulte os nomes das colunas e os tipos de dados de cada uma.
df.dtype

# %%
# Verifique se existem valores ausentes em cada coluna.

# %%
# Gere estatísticas descritivas para as colunas numéricas.

# %%
# Conte quantos clientes existem em cada segmento.

# %%
# Compare as médias dos atributos numéricos agrupando os clientes por segment
